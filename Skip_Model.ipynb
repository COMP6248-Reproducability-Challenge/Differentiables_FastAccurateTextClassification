# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision
    ! pip install --upgrade git+https://github.com/sovrasov/flops-counter.pytorch.git

try:
    import torchtext
except:
    # !pip install torchtext
    
try:
    import spacy
except:
    # !pip install spacy
    
try:
    spacy.load('en')
except:
    # !python -m spacy download en

# %% [markdown]
# # Data loading and pre processing

# %%
import torch
from torchtext import data
import torch.nn.functional as F
from torch import nn
from torch import optim
from torch.distributions import Categorical
from torchtext import datasets

import random
import numpy as np
import os.path

# %%
TEXT = data.Field(tokenize='spacy', lower=True, include_lengths=True)
LABEL = data.LabelField(dtype=torch.float)
_train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
# Out:
# downloading aclImdb_v1.tar.gz
# aclImdb_v1.tar.gz: 100%|██████████| 84.1M/84.1M [00:04<00:00, 18.0MB/s]

# %%
train_data, valid_data = _train_data.split(0.8)

print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 20000
# Number of validation examples: 5000
# Number of testing examples: 25000

# %%
TEXT.build_vocab(train_data, max_size=100000, vectors="glove.6B.100d")
LABEL.build_vocab(train_data)

print(f"Unique tokens in TEXT vocabulary: {len(TEXT.vocab)}")
print(f"Unique tokens in LABEL vocabulary: {len(LABEL.vocab)}")
# Out:
# .vector_cache/glove.6B.zip: 862MB [08:36, 1.67MB/s]
#  99%|█████████▉| 397499/400000 [00:15<00:00, 25993.73it/s]
# Unique tokens in TEXT vocabulary: 91110
# Unique tokens in LABEL vocabulary: 2

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device = 'cpu'
# Assume that we are on a CUDA machine, then this should print a CUDA device:

print(device)
# Out:
# cpu

# %% [markdown]
# # Model and training

# %%
BATCH_SIZE = 50

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size=BATCH_SIZE,
    device=device,
    shuffle = False,
    sort_key=lambda x: len(x.text),
    sort_within_batch=True)

# %%
N = 5 # Max number of jumps allowed
K = 40 # Max jump size
R = 20 # Number of tokens read between every two jumps

def reward_function(prob, true_label):
  """
  Returns 1 if correct prediction, -1 otherwise
  """
  # print("true_label", "prob", true_label, prob)
  if prob>0.5 and true_label>0.5:
    return torch.tensor(1.0, requires_grad=True)
  if prob<0.5 and true_label<0.5:
    return torch.tensor(1.0, requires_grad=True)
  return torch.tensor(-1.0, requires_grad=True)

class SkipReadingModel(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, gamma=0.99, train_mode=True):
        super().__init__()
        
        # store dimensions and constants
        self.input_dim = input_dim
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.gamma = gamma
        self.train_mode = True
        
        # create layers
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        self.lstm_cell = nn.LSTMCell(input_size = embedding_dim, hidden_size = hidden_dim, bias = True)
        self.jumping_linear = nn.Linear(hidden_dim, K+1)
        self.output_linear = nn.Linear(hidden_dim, output_dim)

        # Baseline weight        
        self.wb = nn.Parameter(data=torch.zeros(self.hidden_dim), requires_grad=True)
        self.cb = nn.Parameter(data=torch.tensor((0.0)), requires_grad=True)
        # Initialize lstm_cell states
        self.initialize_lstm_cell_states()
        
        # Initalize episode number and time number
        self.initialize_for_new_batch()
        self.initialize_time_number()
        
        # Overall reward and loss history
        self.reward_history = []
        self.loss_history = []
        self.training_accuracies = []
        self.validation_accuracies = []
        # torch.tensor((0.0), requires_grad=True) 
    
    def initialize_lstm_cell_states(self):
        self.c = torch.zeros(1, self.hidden_dim, requires_grad=True)
        self.h = torch.zeros(1, self.hidden_dim, requires_grad=True)
            
    def initialize_episode_number(self):
        self.ep = 0
    
    def initialize_time_number(self):
        self.t = 0
    
    def clear_batch_lists(self):
        del self.saved_log_probs[:]
        del self.reward_baselines[:]
        del self.rewards[:]
        del self.label_targets[:]
        del self.label_predictions[:]
        self.initialize_episode_number()
        self.training_accuracy = 0.0
    
    def initialize_for_new_batch(self):
        """
        Cleans history of log probabilities, rewards, targets etc for the last
        batch
        """
        self.initialize_episode_number()
        
        # Episode policy and reward history 
        self.saved_log_probs = [] # log probabilities for each time step t in each episode in batch
        self.rewards = [] # reward at final time step of each episode in batch
        self.reward_baselines = [] # reward baselines for each time step t in each episode in batch

        # Predictions and targets history (for cross entropy loss calculation)
        self.label_predictions = [] # 1 probability for each episode
        self.label_targets = []# 1 label for each episode
        self.training_accuracy = 0.0

        
    def classify(self):
        out = self.output_linear(self.c[0])
        self.label_predictions.append(out)
        if self.train_mode:
          self.rewards.append(reward_function(torch.sigmoid(out), self.label_targets[-1]))
        # return torch.sigmoid(out)
       
    def get_baseline(self):
        return torch.dot(self.wb, self.c[0].detach()) + self.cb
    
    def save_training_accuracy(self):
      correct = 0
      for _r in self.rewards:
        if _r > 0:
          correct += 1
      self.training_accuracy = correct/len(self.rewards)
      self.training_accuracies.append(self.training_accuracy)
      
    
    def forward(self, pack):
        texts, lengths, labels = pack
        embeddeds = self.embedding(texts)
        # embeddeds = nn.utils.rnn.pack_padded_sequence(embeddeds, lengths)
        self.initialize_for_new_batch()

        for episode_number in range(embeddeds.shape[1]):
            
            # load episode data
            self.ep = episode_number
            embedded = embeddeds[:, self.ep, :]
      
            #print(texts.shape, embeddeds.shape, embedded.shape)
            #print(label)
            
            # initialize counters and index
            tokens_read = 0
            jumps_made = 0
            word_index = 0
            words_len = embedded.shape[0]
            self.initialize_lstm_cell_states()
            self.initialize_time_number()
            self.saved_log_probs.append([])
            self.reward_baselines.append([])
            
            if self.train_mode:
              label = labels[self.ep].reshape(1)
              self.label_targets.append(label)
            
            # start iterating through sequence, while skipping some words
            while word_index<words_len and word_index<600:
              self.t += 1
              embedded_word = embedded[word_index]
              #print("embedded_word", embedded_word.shape)
              
              # generate next lstm cell state
              self.h, self.c = self.lstm_cell(torch.reshape(embedded_word, (1, -1)), (self.h, self.c))
              # print('word_index', word_index, 'tokens_read', tokens_read, 'jumps_made', jumps_made)
              
              # if time to jump words
              if tokens_read % R==0:
                
                probs = self.jumping_linear(self.c[0])
                probs = F.softmax(probs)
                categ = Categorical(probs)
                k = categ.sample()
                
                # Add log probability of our chosen action to our history
                self.saved_log_probs[-1].append(categ.log_prob(k))
                self.reward_baselines[-1].append(self.get_baseline())
                
                # classify and move to next episode
                if k==0:
                    self.classify()
                    break
                
                # increment counters
                jumps_made += 1
                word_index+=k
              # if not time to jump, then continue to next word
              else:
                word_index+=1
              
              # increment words read so far counter
              tokens_read += 1
              
              # if max amounts of jump made already, 
              # then classify and move to next episode
              if jumps_made == N:
                self.classify()
                break
            else:
              # print("Finished while loop")
              # raise ValueError('Finshed ')
              self.classify()
        if self.train_mode:
            self.save_training_accuracy()
        return self.label_predictions

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 128
OUTPUT_DIM = 1

seed = 7
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

bce = nn.BCEWithLogitsLoss(reduction='mean')
policy_model = SkipReadingModel(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM).to(device)
pretrained_embeddings = TEXT.vocab.vectors
policy_model.embedding.weight.data.copy_(pretrained_embeddings)

if os.path.exists('jump_model.weights'):
  policy_model.load_state_dict(torch.load('jump_model.weights'))

# define the optimiser
optimizer = optim.Adam(policy_model.parameters(), lr=0.001)

# %%
def update_policy():
   
    #print(len(policy_model.rewards), len(policy_model.label_predictions), len(policy_model.label_targets))
    #print(len(policy_model.saved_log_probs), len(policy_model.reward_baselines))
    
    J1 = bce(
        torch.cat(policy_model.label_predictions),
        torch.cat(policy_model.label_targets)
    )
    
    J2 = torch.tensor(0.0, device=device, requires_grad=True)
    J3 = torch.tensor(0.0, device=device, requires_grad=True)
    
    for R, lps, rbs in zip(policy_model.rewards, policy_model.saved_log_probs, policy_model.reward_baselines):
        for log_prob, baseline in zip(lps, rbs):
          weighted_log_prob = (-log_prob * (R - baseline.item()))
          _baseline_loss = torch.pow(R - baseline, 2)
          J2 = J2 + weighted_log_prob
          J3 = J3 + _baseline_loss
    
    optimizer.zero_grad()
    policy_loss =  J1 +  (J2/len(policy_model.rewards)) + J3
    # print('policy_loss', policy_loss)
    policy_loss.backward(retain_graph=True)
    optimizer.step()
    
    policy_model.clear_batch_lists()

# %%
def test_model():
  policy_model.train_mode = True
  correct = 0
  total=0
  for _data in test_iterator:
    # get the inputs
    texts, text_lengths, labels = _data.text[0], _data.text[1], _data.label
    # print("Input review texts, text_lengths, labels", texts.shape, text_lengths.shape, labels.shape)
    predictions = policy_model((texts.to(device), text_lengths.to(device), labels.to(device)))
    for (prediction, label) in zip(predictions, labels):
      if reward_function(label, prediction) > 0:
        correct += 1
      total += 1
    if total%1000 == 0:
      print(total)
    if total%5000 == 0:
      break
  print("Test accuracy :", correct/total)
  policy_model.train_mode = True
  return correct/total

def validate_model():
  policy_model.train_mode = True
  correct = 0
  total=0
  for _data in valid_iterator:
    # get the inputs
    texts, text_lengths, labels = _data.text[0], _data.text[1], _data.label
    # print("Input review texts, text_lengths, labels", texts.shape, text_lengths.shape, labels.shape)
    predictions = policy_model((texts.to(device), text_lengths.to(device), labels.to(device)))
    for (prediction, label) in zip(predictions, labels):
      if reward_function(label, prediction) > 0:
        correct += 1
      total += 1
    if total%1000 == 0:
      break
  print("Validation accuracy :", correct/total)
  policy_model.train_mode = True
  policy_model.validation_accuracies.append(correct/total)
  return correct/total

# test_model()

# %%
# the epoch loop

with torch.enable_grad():
  validate_model()
  for epoch in range(10):
      running_reward = 10
      t = 0
      for _data in train_iterator:
          # get the inputs
          texts, text_lengths, labels = _data.text[0], _data.text[1], _data.label
          # print("Input review texts, text_lengths, labels", texts.shape, text_lengths.shape, labels.shape)
          prediction = policy_model((texts.to(device), text_lengths.to(device), labels.to(device)))
          # print("Prediction", prediction.item())        
          # raise ValueError('Not done')
          t += 1
          if t%2 == 0:
            print("batch no. %d, training accuracy %4.2f" % (t, policy_model.training_accuracy))
          if t%10 == 0:
            validate_model()
            #print("wb", policy_model.wb)
            #print("lstm hh hi", policy_model.lstm_cell.weight_hh, policy_model.lstm_cell.weight_ih)
            #print("emb", policy_model.embedding.weight)
            #print("jmp", policy_model.jumping_linear.weight)
            #print("out", policy_model.output_linear.weight)
          if t%1000 == 0:
            break
          update_policy()
      #running_reward = 0.05 * policy_model.reward_episode + (1 - 0.05) * running_reward
      #print("Epoch %d, reward %4.2f" % (epoch, running_reward))
      print("Epoch %d" % (epoch))
  print('**** Finished Training ****')
# test_model()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Validation accuracy : 0.54
# batch no. 2, training accuracy 0.60
# batch no. 4, training accuracy 0.54
# batch no. 6, training accuracy 0.54
# batch no. 8, training accuracy 0.60
# batch no. 10, training accuracy 0.42
# Validation accuracy : 0.54
# batch no. 12, training accuracy 0.60
# batch no. 14, training accuracy 0.54
# batch no. 16, training accuracy 0.56
# batch no. 18, training accuracy 0.48
# batch no. 20, training accuracy 0.60
# Validation accuracy : 0.54
# batch no. 22, training accuracy 0.50
# batch no. 24, training accuracy 0.50
# batch no. 26, training accuracy 0.62
# batch no. 28, training accuracy 0.42
# batch no. 30, training accuracy 0.48
# Validation accuracy : 0.54
# batch no. 32, training accuracy 0.54
# batch no. 34, training accuracy 0.62
# batch no. 36, training accuracy 0.54
# batch no. 38, training accuracy 0.42
# batch no. 40, training accuracy 0.40
# Validation accuracy : 0.54
# batch no. 42, training accuracy 0.58
# batch no. 44, training accuracy 0.58
# batch no. 46, training accuracy 0.64
# batch no. 48, training accuracy 0.48
# batch no. 50, training accuracy 0.46
# Validation accuracy : 0.542
# batch no. 52, training accuracy 0.50
# batch no. 54, training accuracy 0.58
# batch no. 56, training accuracy 0.46
# batch no. 58, training accuracy 0.54
# batch no. 60, training accuracy 0.48
# Validation accuracy : 0.54
# batch no. 62, training accuracy 0.52
# batch no. 64, training accuracy 0.60
# batch no. 66, training accuracy 0.52
# batch no. 68, training accuracy 0.44
# batch no. 70, training accuracy 0.56
# Validation accuracy : 0.547
# batch no. 72, training accuracy 0.40
# batch no. 74, training accuracy 0.52
# batch no. 76, training accuracy 0.56
# batch no. 78, training accuracy 0.64
# batch no. 80, training accuracy 0.46
# Validation accuracy : 0.54
# batch no. 82, training accuracy 0.52
# batch no. 84, training accuracy 0.54
# batch no. 86, training accuracy 0.52
# batch no. 88, training accuracy 0.54
# batch no. 90, training accuracy 0.48
# Validation accuracy : 0.571
# batch no. 92, training accuracy 0.42
# batch no. 94, training accuracy 0.42
# batch no. 96, training accuracy 0.54
# batch no. 98, training accuracy 0.60
# batch no. 100, training accuracy 0.56
# Validation accuracy : 0.54
# batch no. 102, training accuracy 0.42
# batch no. 104, training accuracy 0.42
# batch no. 106, training accuracy 0.42
# batch no. 108, training accuracy 0.56
# batch no. 110, training accuracy 0.68
# Validation accuracy : 0.54
# batch no. 112, training accuracy 0.42
# batch no. 114, training accuracy 0.38
# batch no. 116, training accuracy 0.40
# batch no. 118, training accuracy 0.60
# batch no. 120, training accuracy 0.58
# Validation accuracy : 0.542
# batch no. 122, training accuracy 0.52
# batch no. 124, training accuracy 0.64
# batch no. 126, training accuracy 0.56
# batch no. 128, training accuracy 0.44
# batch no. 130, training accuracy 0.54
# Validation accuracy : 0.561
# batch no. 132, training accuracy 0.48
# batch no. 134, training accuracy 0.66
# batch no. 136, training accuracy 0.50
# batch no. 138, training accuracy 0.66
# batch no. 140, training accuracy 0.54
# Validation accuracy : 0.543
# batch no. 142, training accuracy 0.54
# batch no. 144, training accuracy 0.52
# batch no. 146, training accuracy 0.42
# batch no. 148, training accuracy 0.56
# batch no. 150, training accuracy 0.64
# Validation accuracy : 0.542
# batch no. 152, training accuracy 0.56
# batch no. 154, training accuracy 0.46
# batch no. 156, training accuracy 0.56
# batch no. 158, training accuracy 0.44
# batch no. 160, training accuracy 0.58
# Validation accuracy : 0.556
# batch no. 162, training accuracy 0.70
# batch no. 164, training accuracy 0.56
# batch no. 166, training accuracy 0.60
# batch no. 168, training accuracy 0.66
# batch no. 170, training accuracy 0.60
# Validation accuracy : 0.55
# batch no. 172, training accuracy 0.56
# batch no. 174, training accuracy 0.76
# batch no. 176, training accuracy 0.48
# batch no. 178, training accuracy 0.60
# batch no. 180, training accuracy 0.48
# Validation accuracy : 0.562
# batch no. 182, training accuracy 0.48
# batch no. 184, training accuracy 0.60
# batch no. 186, training accuracy 0.54
# batch no. 188, training accuracy 0.56
# batch no. 190, training accuracy 0.62
# Validation accuracy : 0.578
# batch no. 192, training accuracy 0.58
# batch no. 194, training accuracy 0.62
# batch no. 196, training accuracy 0.72
# batch no. 198, training accuracy 0.66
# batch no. 200, training accuracy 0.60
# Validation accuracy : 0.543
# batch no. 202, training accuracy 0.64
# batch no. 204, training accuracy 0.54
# batch no. 206, training accuracy 0.48
# batch no. 208, training accuracy 0.60
# batch no. 210, training accuracy 0.62
# Validation accuracy : 0.568
# batch no. 212, training accuracy 0.50
# batch no. 214, training accuracy 0.58
# batch no. 216, training accuracy 0.62
# batch no. 218, training accuracy 0.72
# batch no. 220, training accuracy 0.60
# Validation accuracy : 0.565
# batch no. 222, training accuracy 0.72
# batch no. 224, training accuracy 0.74
# batch no. 226, training accuracy 0.80
# batch no. 228, training accuracy 0.78
# batch no. 230, training accuracy 0.60
# Validation accuracy : 0.706
# batch no. 232, training accuracy 0.66
# batch no. 234, training accuracy 0.66
# batch no. 236, training accuracy 0.54
# batch no. 238, training accuracy 0.54
# batch no. 240, training accuracy 0.60
# Validation accuracy : 0.567
# batch no. 242, training accuracy 0.72
# batch no. 244, training accuracy 0.62
# batch no. 246, training accuracy 0.72
# batch no. 248, training accuracy 0.66
# batch no. 250, training accuracy 0.58
# Validation accuracy : 0.678
# batch no. 252, training accuracy 0.76
# batch no. 254, training accuracy 0.64
# batch no. 256, training accuracy 0.72
# batch no. 258, training accuracy 0.58
# batch no. 260, training accuracy 0.74
# Validation accuracy : 0.709
# batch no. 262, training accuracy 0.66
# batch no. 264, training accuracy 0.66
# batch no. 266, training accuracy 0.62
# batch no. 268, training accuracy 0.60
# batch no. 270, training accuracy 0.70
# Validation accuracy : 0.732
# batch no. 272, training accuracy 0.70
# batch no. 274, training accuracy 0.68
# batch no. 276, training accuracy 0.56
# batch no. 278, training accuracy 0.66
# batch no. 280, training accuracy 0.74
# Validation accuracy : 0.685
# batch no. 282, training accuracy 0.70
# batch no. 284, training accuracy 0.54
# batch no. 286, training accuracy 0.62
# batch no. 288, training accuracy 0.66
# batch no. 290, training accuracy 0.66
# Validation accuracy : 0.699
# batch no. 292, training accuracy 0.60
# batch no. 294, training accuracy 0.60
# batch no. 296, training accuracy 0.56
# batch no. 298, training accuracy 0.68
# batch no. 300, training accuracy 0.56
# Validation accuracy : 0.579
# batch no. 302, training accuracy 0.72
# batch no. 304, training accuracy 0.76
# batch no. 306, training accuracy 0.68
# batch no. 308, training accuracy 0.72
# batch no. 310, training accuracy 0.62
# Validation accuracy : 0.668
# batch no. 312, training accuracy 0.70
# batch no. 314, training accuracy 0.84
# batch no. 316, training accuracy 0.70
# batch no. 318, training accuracy 0.78
# batch no. 320, training accuracy 0.68
# Validation accuracy : 0.707
# batch no. 322, training accuracy 0.72
# batch no. 324, training accuracy 0.86
# batch no. 326, training accuracy 0.64
# batch no. 328, training accuracy 0.66
# batch no. 330, training accuracy 0.80
# Validation accuracy : 0.764
# batch no. 332, training accuracy 0.56
# batch no. 334, training accuracy 0.74
# batch no. 336, training accuracy 0.76
# batch no. 338, training accuracy 0.58
# batch no. 340, training accuracy 0.76
# Validation accuracy : 0.709
# batch no. 342, training accuracy 0.80
# batch no. 344, training accuracy 0.64
# batch no. 346, training accuracy 0.88
# batch no. 348, training accuracy 0.72
# batch no. 350, training accuracy 0.80
# Validation accuracy : 0.714
# batch no. 352, training accuracy 0.74
# batch no. 354, training accuracy 0.78
# batch no. 356, training accuracy 0.78
# batch no. 358, training accuracy 0.76
# batch no. 360, training accuracy 0.74
# Validation accuracy : 0.762
# batch no. 362, training accuracy 0.68
# batch no. 364, training accuracy 0.64
# batch no. 366, training accuracy 0.60
# batch no. 368, training accuracy 0.84
# batch no. 370, training accuracy 0.68
# Validation accuracy : 0.756
# batch no. 372, training accuracy 0.70
# batch no. 374, training accuracy 0.56
# batch no. 376, training accuracy 0.76
# batch no. 378, training accuracy 0.62
# batch no. 380, training accuracy 0.78
# Validation accuracy : 0.759
# batch no. 382, training accuracy 0.76
# batch no. 384, training accuracy 0.70
# batch no. 386, training accuracy 0.74
# batch no. 388, training accuracy 0.60
# batch no. 390, training accuracy 0.72
# Validation accuracy : 0.753
# batch no. 392, training accuracy 0.68
# batch no. 394, training accuracy 0.58
# batch no. 396, training accuracy 0.60
# batch no. 398, training accuracy 0.68
# batch no. 400, training accuracy 0.64
# Validation accuracy : 0.762
# Epoch 0
# batch no. 2, training accuracy 0.62
# batch no. 4, training accuracy 0.74
# batch no. 6, training accuracy 0.64
# batch no. 8, training accuracy 0.66
# batch no. 10, training accuracy 0.70
# Validation accuracy : 0.697
# batch no. 12, training accuracy 0.82
# batch no. 14, training accuracy 0.76
# batch no. 16, training accuracy 0.78
# batch no. 18, training accuracy 0.84
# batch no. 20, training accuracy 0.86
# Validation accuracy : 0.76
# batch no. 22, training accuracy 0.76
# batch no. 24, training accuracy 0.70
# batch no. 26, training accuracy 0.78
# batch no. 28, training accuracy 0.84
# batch no. 30, training accuracy 0.84
# Validation accuracy : 0.767
# batch no. 32, training accuracy 0.80
# batch no. 34, training accuracy 0.76
# batch no. 36, training accuracy 0.82
# batch no. 38, training accuracy 0.60
# batch no. 40, training accuracy 0.78
# Validation accuracy : 0.766
# batch no. 42, training accuracy 0.84
# batch no. 44, training accuracy 0.78
# batch no. 46, training accuracy 0.80
# batch no. 48, training accuracy 0.80
# batch no. 50, training accuracy 0.78
# Validation accuracy : 0.78
# batch no. 52, training accuracy 0.82
# batch no. 54, training accuracy 0.74
# batch no. 56, training accuracy 0.82
# batch no. 58, training accuracy 0.74
# batch no. 60, training accuracy 0.72
# Validation accuracy : 0.765
# batch no. 62, training accuracy 0.80
# batch no. 64, training accuracy 0.72
# batch no. 66, training accuracy 0.90
# batch no. 68, training accuracy 0.72
# batch no. 70, training accuracy 0.76
# Validation accuracy : 0.795
# batch no. 72, training accuracy 0.72
# batch no. 74, training accuracy 0.74
# batch no. 76, training accuracy 0.78
# batch no. 78, training accuracy 0.84
# batch no. 80, training accuracy 0.74
# Validation accuracy : 0.788
# batch no. 82, training accuracy 0.78
# batch no. 84, training accuracy 0.64
# batch no. 86, training accuracy 0.78
# batch no. 88, training accuracy 0.74
# batch no. 90, training accuracy 0.72
# Validation accuracy : 0.764
# batch no. 92, training accuracy 0.78
# batch no. 94, training accuracy 0.80
# batch no. 96, training accuracy 0.64
# batch no. 98, training accuracy 0.62
# batch no. 100, training accuracy 0.80
# Validation accuracy : 0.773
# batch no. 102, training accuracy 0.76
# batch no. 104, training accuracy 0.64
# batch no. 106, training accuracy 0.70
# batch no. 108, training accuracy 0.74
# batch no. 110, training accuracy 0.76
# Validation accuracy : 0.737
# batch no. 112, training accuracy 0.74
# batch no. 114, training accuracy 0.76
# batch no. 116, training accuracy 0.80
# batch no. 118, training accuracy 0.84
# batch no. 120, training accuracy 0.90
# Validation accuracy : 0.785
# batch no. 122, training accuracy 0.84
# batch no. 124, training accuracy 0.88
# batch no. 126, training accuracy 0.74
# batch no. 128, training accuracy 0.76
# batch no. 130, training accuracy 0.76
# Validation accuracy : 0.799
# batch no. 132, training accuracy 0.76
# batch no. 134, training accuracy 0.80
# batch no. 136, training accuracy 0.76
# batch no. 138, training accuracy 0.70
# batch no. 140, training accuracy 0.78
# Validation accuracy : 0.774
# batch no. 142, training accuracy 0.74
# batch no. 144, training accuracy 0.84
# batch no. 146, training accuracy 0.76
# batch no. 148, training accuracy 0.74
# batch no. 150, training accuracy 0.78
# Validation accuracy : 0.746
# batch no. 152, training accuracy 0.78
# batch no. 154, training accuracy 0.72
# batch no. 156, training accuracy 0.84
# batch no. 158, training accuracy 0.74
# batch no. 160, training accuracy 0.78
# Validation accuracy : 0.737
# batch no. 162, training accuracy 0.80
# batch no. 164, training accuracy 0.80
# batch no. 166, training accuracy 0.82
# batch no. 168, training accuracy 0.76
# batch no. 170, training accuracy 0.72
# Validation accuracy : 0.765
# batch no. 172, training accuracy 0.68
# batch no. 174, training accuracy 0.72
# batch no. 176, training accuracy 0.80
# batch no. 178, training accuracy 0.76
# batch no. 180, training accuracy 0.70
# Validation accuracy : 0.771
# batch no. 182, training accuracy 0.70
# batch no. 184, training accuracy 0.82
# batch no. 186, training accuracy 0.64
# batch no. 188, training accuracy 0.66
# batch no. 190, training accuracy 0.76
# Validation accuracy : 0.783
# batch no. 192, training accuracy 0.60
# batch no. 194, training accuracy 0.80
# batch no. 196, training accuracy 0.72
# batch no. 198, training accuracy 0.76
# batch no. 200, training accuracy 0.70
# Validation accuracy : 0.766
# batch no. 202, training accuracy 0.82
# batch no. 204, training accuracy 0.86
# batch no. 206, training accuracy 0.80
# batch no. 208, training accuracy 0.90
# batch no. 210, training accuracy 0.82
# Validation accuracy : 0.774
# batch no. 212, training accuracy 0.72
# batch no. 214, training accuracy 0.74
# batch no. 216, training accuracy 0.80
# batch no. 218, training accuracy 0.74
# batch no. 220, training accuracy 0.82
# Validation accuracy : 0.797
# batch no. 222, training accuracy 0.88
# batch no. 224, training accuracy 0.88
# batch no. 226, training accuracy 0.86
# batch no. 228, training accuracy 0.84
# batch no. 230, training accuracy 0.70
# Validation accuracy : 0.797
# batch no. 232, training accuracy 0.90
# batch no. 234, training accuracy 0.88
# batch no. 236, training accuracy 0.72
# batch no. 238, training accuracy 0.84
# batch no. 240, training accuracy 0.86
# Validation accuracy : 0.794
# batch no. 242, training accuracy 0.94
# batch no. 244, training accuracy 0.78
# batch no. 246, training accuracy 0.84
# batch no. 248, training accuracy 0.82
# batch no. 250, training accuracy 0.72
# Validation accuracy : 0.786
# batch no. 252, training accuracy 0.90
# batch no. 254, training accuracy 0.76
# batch no. 256, training accuracy 0.84
# batch no. 258, training accuracy 0.80
# batch no. 260, training accuracy 0.88
# Validation accuracy : 0.797
# batch no. 262, training accuracy 0.88
# batch no. 264, training accuracy 0.84
# batch no. 266, training accuracy 0.86
# batch no. 268, training accuracy 0.78
# batch no. 270, training accuracy 0.82
# Validation accuracy : 0.761
# batch no. 272, training accuracy 0.78
# batch no. 274, training accuracy 0.78
# batch no. 276, training accuracy 0.78
# batch no. 278, training accuracy 0.80
# batch no. 280, training accuracy 0.76
# Validation accuracy : 0.743
# batch no. 282, training accuracy 0.84
# batch no. 284, training accuracy 0.78
# batch no. 286, training accuracy 0.82
# batch no. 288, training accuracy 0.70
# batch no. 290, training accuracy 0.74
# Validation accuracy : 0.793
# batch no. 292, training accuracy 0.72
# batch no. 294, training accuracy 0.72
# batch no. 296, training accuracy 0.78
# batch no. 298, training accuracy 0.74
# batch no. 300, training accuracy 0.54
# Validation accuracy : 0.803
# batch no. 302, training accuracy 0.88
# batch no. 304, training accuracy 0.86
# batch no. 306, training accuracy 0.66
# batch no. 308, training accuracy 0.78
# batch no. 310, training accuracy 0.84
# Validation accuracy : 0.778
# batch no. 312, training accuracy 0.78
# batch no. 314, training accuracy 0.80
# batch no. 316, training accuracy 0.74
# batch no. 318, training accuracy 0.88
# batch no. 320, training accuracy 0.68
# Validation accuracy : 0.777
# batch no. 322, training accuracy 0.82
# batch no. 324, training accuracy 0.90
# batch no. 326, training accuracy 0.82
# batch no. 328, training accuracy 0.78
# batch no. 330, training accuracy 0.90
# Validation accuracy : 0.794
# batch no. 332, training accuracy 0.82
# batch no. 334, training accuracy 0.82
# batch no. 336, training accuracy 0.78
# batch no. 338, training accuracy 0.82
# batch no. 340, training accuracy 0.94
# Validation accuracy : 0.8
# batch no. 342, training accuracy 0.88
# batch no. 344, training accuracy 0.78
# batch no. 346, training accuracy 0.82
# batch no. 348, training accuracy 0.86
# batch no. 350, training accuracy 0.90
# Validation accuracy : 0.776
# batch no. 352, training accuracy 0.84
# batch no. 354, training accuracy 0.84
# batch no. 356, training accuracy 0.82
# batch no. 358, training accuracy 0.88
# batch no. 360, training accuracy 0.76
# Validation accuracy : 0.798
# batch no. 362, training accuracy 0.84
# batch no. 364, training accuracy 0.80
# batch no. 366, training accuracy 0.80
# batch no. 368, training accuracy 0.80
# batch no. 370, training accuracy 0.68
# Validation accuracy : 0.789
# batch no. 372, training accuracy 0.88
# batch no. 374, training accuracy 0.78
# batch no. 376, training accuracy 0.78
# batch no. 378, training accuracy 0.72
# batch no. 380, training accuracy 0.82
# Validation accuracy : 0.789
# batch no. 382, training accuracy 0.82
# batch no. 384, training accuracy 0.80
# batch no. 386, training accuracy 0.84
# batch no. 388, training accuracy 0.76
# batch no. 390, training accuracy 0.74
# Validation accuracy : 0.805
# batch no. 392, training accuracy 0.80
# batch no. 394, training accuracy 0.74
# batch no. 396, training accuracy 0.64
# batch no. 398, training accuracy 0.76
# batch no. 400, training accuracy 0.64
# Validation accuracy : 0.74
# Epoch 1
# batch no. 2, training accuracy 0.70
# batch no. 4, training accuracy 0.72
# batch no. 6, training accuracy 0.82
# batch no. 8, training accuracy 0.74
# batch no. 10, training accuracy 0.78
# Validation accuracy : 0.782
# batch no. 12, training accuracy 0.90
# batch no. 14, training accuracy 0.80
# batch no. 16, training accuracy 0.84
# batch no. 18, training accuracy 0.86
# batch no. 20, training accuracy 0.88
# Validation accuracy : 0.8
# batch no. 22, training accuracy 0.88
# batch no. 24, training accuracy 0.82
# batch no. 26, training accuracy 0.86
# batch no. 28, training accuracy 0.88
# batch no. 30, training accuracy 0.90
# Validation accuracy : 0.817
# batch no. 32, training accuracy 0.82
# batch no. 34, training accuracy 0.80
# batch no. 36, training accuracy 0.80
# batch no. 38, training accuracy 0.82
# batch no. 40, training accuracy 0.82
# Validation accuracy : 0.784
# batch no. 42, training accuracy 0.92
# batch no. 44, training accuracy 0.84
# batch no. 46, training accuracy 0.80
# batch no. 48, training accuracy 0.80
# batch no. 50, training accuracy 0.80
# Validation accuracy : 0.783
# batch no. 52, training accuracy 0.84
# batch no. 54, training accuracy 0.86
# batch no. 56, training accuracy 0.88
# batch no. 58, training accuracy 0.90
# batch no. 60, training accuracy 0.80
# Validation accuracy : 0.787
# batch no. 62, training accuracy 0.88
# batch no. 64, training accuracy 0.86
# batch no. 66, training accuracy 0.82
# batch no. 68, training accuracy 0.84
# batch no. 70, training accuracy 0.66
# Validation accuracy : 0.792
# batch no. 72, training accuracy 0.82
# batch no. 74, training accuracy 0.82
# batch no. 76, training accuracy 0.88
# batch no. 78, training accuracy 0.88
# batch no. 80, training accuracy 0.78
# Validation accuracy : 0.814
# batch no. 82, training accuracy 0.76
# batch no. 84, training accuracy 0.72
# batch no. 86, training accuracy 0.88
# batch no. 88, training accuracy 0.88
# batch no. 90, training accuracy 0.82
# Validation accuracy : 0.805
# batch no. 92, training accuracy 0.88
# batch no. 94, training accuracy 0.82
# batch no. 96, training accuracy 0.78
# batch no. 98, training accuracy 0.76
# batch no. 100, training accuracy 0.76
# Validation accuracy : 0.772
# batch no. 102, training accuracy 0.82
# batch no. 104, training accuracy 0.74
# batch no. 106, training accuracy 0.80
# batch no. 108, training accuracy 0.86
# batch no. 110, training accuracy 0.84
# Validation accuracy : 0.779
# batch no. 112, training accuracy 0.80
# batch no. 114, training accuracy 0.86
# batch no. 116, training accuracy 0.88
# batch no. 118, training accuracy 0.86
# batch no. 120, training accuracy 0.96
# Validation accuracy : 0.787
# batch no. 122, training accuracy 0.96
# batch no. 124, training accuracy 0.90
# batch no. 126, training accuracy 0.84
# batch no. 128, training accuracy 0.84
# batch no. 130, training accuracy 0.78
# Validation accuracy : 0.755
# batch no. 132, training accuracy 0.78
# batch no. 134, training accuracy 0.78
# batch no. 136, training accuracy 0.82
# batch no. 138, training accuracy 0.80
# batch no. 140, training accuracy 0.78
# Validation accuracy : 0.765
# batch no. 142, training accuracy 0.78
# batch no. 144, training accuracy 0.90
# batch no. 146, training accuracy 0.86
# batch no. 148, training accuracy 0.82
# batch no. 150, training accuracy 0.80
# Validation accuracy : 0.785
# batch no. 152, training accuracy 0.88
# batch no. 154, training accuracy 0.82
# batch no. 156, training accuracy 0.88
# batch no. 158, training accuracy 0.84
# batch no. 160, training accuracy 0.84
# Validation accuracy : 0.755
# batch no. 162, training accuracy 0.86
# batch no. 164, training accuracy 0.84
# batch no. 166, training accuracy 0.88
# batch no. 168, training accuracy 0.90
# batch no. 170, training accuracy 0.78
# Validation accuracy : 0.783
# batch no. 172, training accuracy 0.76
# batch no. 174, training accuracy 0.90
# batch no. 176, training accuracy 0.88
# batch no. 178, training accuracy 0.90
# batch no. 180, training accuracy 0.76
# Validation accuracy : 0.78
# batch no. 182, training accuracy 0.82
# batch no. 184, training accuracy 0.90
# batch no. 186, training accuracy 0.78
# batch no. 188, training accuracy 0.78
# batch no. 190, training accuracy 0.86
# Validation accuracy : 0.798
# batch no. 192, training accuracy 0.76
# batch no. 194, training accuracy 0.86
# batch no. 196, training accuracy 0.78
# batch no. 198, training accuracy 0.74
# batch no. 200, training accuracy 0.76
# Validation accuracy : 0.732
# batch no. 202, training accuracy 0.82
# batch no. 204, training accuracy 0.84
# batch no. 206, training accuracy 0.78
# batch no. 208, training accuracy 0.92
# batch no. 210, training accuracy 0.74
# Validation accuracy : 0.802
# batch no. 212, training accuracy 0.80
# batch no. 214, training accuracy 0.84
# batch no. 216, training accuracy 0.84
# batch no. 218, training accuracy 0.88
# batch no. 220, training accuracy 0.90
# Validation accuracy : 0.793
# batch no. 222, training accuracy 0.90
# batch no. 224, training accuracy 0.88
# batch no. 226, training accuracy 0.92
# batch no. 228, training accuracy 0.86
# batch no. 230, training accuracy 0.68
# Validation accuracy : 0.812
# batch no. 232, training accuracy 0.92
# batch no. 234, training accuracy 0.82
# batch no. 236, training accuracy 0.76
# batch no. 238, training accuracy 0.88
# batch no. 240, training accuracy 0.88
# Validation accuracy : 0.805
# batch no. 242, training accuracy 0.90
# batch no. 244, training accuracy 0.86
# batch no. 246, training accuracy 0.86
# batch no. 248, training accuracy 0.92
# batch no. 250, training accuracy 0.70
# Validation accuracy : 0.808
# batch no. 252, training accuracy 0.90
# batch no. 254, training accuracy 0.86
# batch no. 256, training accuracy 0.86
# batch no. 258, training accuracy 0.88
# batch no. 260, training accuracy 0.80
# Validation accuracy : 0.786
# batch no. 262, training accuracy 0.92
# batch no. 264, training accuracy 0.88
# batch no. 266, training accuracy 0.88
# batch no. 268, training accuracy 0.90
# batch no. 270, training accuracy 0.80
# Validation accuracy : 0.762
# batch no. 272, training accuracy 0.84
# batch no. 274, training accuracy 0.90
# batch no. 276, training accuracy 0.84
# batch no. 278, training accuracy 0.90
# batch no. 280, training accuracy 0.74
# Validation accuracy : 0.798
# batch no. 282, training accuracy 0.86
# batch no. 284, training accuracy 0.78
# batch no. 286, training accuracy 0.84
# batch no. 288, training accuracy 0.84
# batch no. 290, training accuracy 0.82
# Validation accuracy : 0.786
# batch no. 292, training accuracy 0.86
# batch no. 294, training accuracy 0.80
# batch no. 296, training accuracy 0.84
# batch no. 298, training accuracy 0.88
# batch no. 300, training accuracy 0.76
# Validation accuracy : 0.767
# batch no. 302, training accuracy 0.86
# batch no. 304, training accuracy 0.84
# batch no. 306, training accuracy 0.74
# batch no. 308, training accuracy 0.86
# batch no. 310, training accuracy 0.80
# Validation accuracy : 0.8
# batch no. 312, training accuracy 0.80
# batch no. 314, training accuracy 0.84
# batch no. 316, training accuracy 0.92
# batch no. 318, training accuracy 0.86
# batch no. 320, training accuracy 0.78
# Validation accuracy : 0.801
# batch no. 322, training accuracy 0.88
# batch no. 324, training accuracy 0.92
# batch no. 326, training accuracy 0.90
# batch no. 328, training accuracy 0.90
# batch no. 330, training accuracy 0.80
# Validation accuracy : 0.788
# batch no. 332, training accuracy 0.92
# batch no. 334, training accuracy 0.82
# batch no. 336, training accuracy 0.94
# batch no. 338, training accuracy 0.78
# batch no. 340, training accuracy 0.88
# Validation accuracy : 0.787
# batch no. 342, training accuracy 0.96
# batch no. 344, training accuracy 0.86
# batch no. 346, training accuracy 0.90
# batch no. 348, training accuracy 0.94
# batch no. 350, training accuracy 0.86
# Validation accuracy : 0.776
# batch no. 352, training accuracy 0.92
# batch no. 354, training accuracy 0.84
# batch no. 356, training accuracy 0.90
# batch no. 358, training accuracy 0.94
# batch no. 360, training accuracy 0.82
# Validation accuracy : 0.796
# batch no. 362, training accuracy 0.90
# batch no. 364, training accuracy 0.82
# batch no. 366, training accuracy 0.90
# batch no. 368, training accuracy 0.92
# batch no. 370, training accuracy 0.74
# Validation accuracy : 0.785
# batch no. 372, training accuracy 0.96
# batch no. 374, training accuracy 0.90
# batch no. 376, training accuracy 0.90
# batch no. 378, training accuracy 0.86
# batch no. 380, training accuracy 0.76
# Validation accuracy : 0.777
# batch no. 382, training accuracy 0.80
# batch no. 384, training accuracy 0.86
# batch no. 386, training accuracy 0.86
# batch no. 388, training accuracy 0.86
# batch no. 390, training accuracy 0.82
# Validation accuracy : 0.789
# batch no. 392, training accuracy 0.80
# batch no. 394, training accuracy 0.86
# batch no. 396, training accuracy 0.86
# batch no. 398, training accuracy 0.94
# batch no. 400, training accuracy 0.68
# Validation accuracy : 0.755
# Epoch 2
# batch no. 2, training accuracy 0.74
# batch no. 4, training accuracy 0.76
# batch no. 6, training accuracy 0.82
# batch no. 8, training accuracy 0.84
# batch no. 10, training accuracy 0.84
# Validation accuracy : 0.786
# batch no. 12, training accuracy 0.90
# batch no. 14, training accuracy 0.88
# batch no. 16, training accuracy 0.86
# batch no. 18, training accuracy 0.92
# batch no. 20, training accuracy 0.86
# Validation accuracy : 0.776
# batch no. 22, training accuracy 0.96
# batch no. 24, training accuracy 0.86
# batch no. 26, training accuracy 0.92
# batch no. 28, training accuracy 0.90
# batch no. 30, training accuracy 0.84
# Validation accuracy : 0.788
# batch no. 32, training accuracy 0.84
# batch no. 34, training accuracy 0.92
# batch no. 36, training accuracy 0.86
# batch no. 38, training accuracy 0.88
# batch no. 40, training accuracy 0.74
# Validation accuracy : 0.771
# batch no. 42, training accuracy 1.00
# batch no. 44, training accuracy 0.94
# batch no. 46, training accuracy 0.92
# batch no. 48, training accuracy 0.90
# batch no. 50, training accuracy 0.80
# Validation accuracy : 0.783
# batch no. 52, training accuracy 0.92
# batch no. 54, training accuracy 0.90
# batch no. 56, training accuracy 0.94
# batch no. 58, training accuracy 0.96
# batch no. 60, training accuracy 0.80
# Validation accuracy : 0.772
# batch no. 62, training accuracy 0.92
# batch no. 64, training accuracy 0.92
# batch no. 66, training accuracy 0.94
# batch no. 68, training accuracy 0.90
# batch no. 70, training accuracy 0.70
# Validation accuracy : 0.774
# batch no. 72, training accuracy 0.92
# batch no. 74, training accuracy 0.98
# batch no. 76, training accuracy 0.90
# batch no. 78, training accuracy 0.86
# batch no. 80, training accuracy 0.78
# Validation accuracy : 0.778
# batch no. 82, training accuracy 0.92
# batch no. 84, training accuracy 0.80
# batch no. 86, training accuracy 0.92
# batch no. 88, training accuracy 0.92
# batch no. 90, training accuracy 0.78
# Validation accuracy : 0.776
# batch no. 92, training accuracy 0.88
# batch no. 94, training accuracy 0.92
# batch no. 96, training accuracy 0.86
# batch no. 98, training accuracy 0.94
# batch no. 100, training accuracy 0.82
# Validation accuracy : 0.766
# batch no. 102, training accuracy 0.88
# batch no. 104, training accuracy 0.80
# batch no. 106, training accuracy 0.86
# batch no. 108, training accuracy 0.94
# batch no. 110, training accuracy 0.80
# Validation accuracy : 0.783
# batch no. 112, training accuracy 0.82
# batch no. 114, training accuracy 0.88
# batch no. 116, training accuracy 0.86
# batch no. 118, training accuracy 0.90
# batch no. 120, training accuracy 0.88
# Validation accuracy : 0.783
# batch no. 122, training accuracy 0.98
# batch no. 124, training accuracy 0.96
# batch no. 126, training accuracy 0.98
# batch no. 128, training accuracy 0.90
# batch no. 130, training accuracy 0.84
# Validation accuracy : 0.788
# batch no. 132, training accuracy 0.90
# batch no. 134, training accuracy 0.88
# batch no. 136, training accuracy 0.88
# batch no. 138, training accuracy 0.88
# batch no. 140, training accuracy 0.78
# Validation accuracy : 0.788
# batch no. 142, training accuracy 0.90
# batch no. 144, training accuracy 0.94
# batch no. 146, training accuracy 0.94
# batch no. 148, training accuracy 0.90
# batch no. 150, training accuracy 0.78
# Validation accuracy : 0.772
# batch no. 152, training accuracy 0.90
# batch no. 154, training accuracy 0.96
# batch no. 156, training accuracy 0.88
# batch no. 158, training accuracy 0.82
# batch no. 160, training accuracy 0.82
# Validation accuracy : 0.785
# batch no. 162, training accuracy 0.92
# batch no. 164, training accuracy 0.92
# batch no. 166, training accuracy 0.90
# batch no. 168, training accuracy 0.92
# batch no. 170, training accuracy 0.78
# Validation accuracy : 0.779
# batch no. 172, training accuracy 0.86
# batch no. 174, training accuracy 0.90
# batch no. 176, training accuracy 0.94
# batch no. 178, training accuracy 0.98
# batch no. 180, training accuracy 0.72
# Validation accuracy : 0.79
# batch no. 182, training accuracy 0.94
# batch no. 184, training accuracy 0.94
# batch no. 186, training accuracy 0.96
# batch no. 188, training accuracy 0.90
# batch no. 190, training accuracy 0.76
# Validation accuracy : 0.782
# batch no. 192, training accuracy 0.94
# batch no. 194, training accuracy 0.94
# batch no. 196, training accuracy 0.96
# batch no. 198, training accuracy 0.80
# batch no. 200, training accuracy 0.72
# Validation accuracy : 0.761
# batch no. 202, training accuracy 0.84
# batch no. 204, training accuracy 0.82
# batch no. 206, training accuracy 0.80
# batch no. 208, training accuracy 0.98
# batch no. 210, training accuracy 0.74
# Validation accuracy : 0.773
# batch no. 212, training accuracy 0.90
# batch no. 214, training accuracy 0.92
# batch no. 216, training accuracy 0.92
# batch no. 218, training accuracy 0.92
# batch no. 220, training accuracy 0.86
# Validation accuracy : 0.766
# batch no. 222, training accuracy 0.94
# batch no. 224, training accuracy 0.94
# batch no. 226, training accuracy 0.92
# batch no. 228, training accuracy 0.90
# batch no. 230, training accuracy 0.58
# Validation accuracy : 0.784
# batch no. 232, training accuracy 1.00
# batch no. 234, training accuracy 0.92
# batch no. 236, training accuracy 0.90
# batch no. 238, training accuracy 0.92
# batch no. 240, training accuracy 0.88
# Validation accuracy : 0.777
# batch no. 242, training accuracy 0.96
# batch no. 244, training accuracy 0.94
# batch no. 246, training accuracy 0.94
# batch no. 248, training accuracy 0.92
# batch no. 250, training accuracy 0.72
# Validation accuracy : 0.783
# batch no. 252, training accuracy 0.92
# batch no. 254, training accuracy 0.92
# batch no. 256, training accuracy 0.88
# batch no. 258, training accuracy 0.90
# batch no. 260, training accuracy 0.86
# Validation accuracy : 0.771
# batch no. 262, training accuracy 0.90
# batch no. 264, training accuracy 0.94
# batch no. 266, training accuracy 0.94
# batch no. 268, training accuracy 0.96
# batch no. 270, training accuracy 0.90
# Validation accuracy : 0.768
# batch no. 272, training accuracy 0.94
# batch no. 274, training accuracy 0.92
# batch no. 276, training accuracy 0.92
# batch no. 278, training accuracy 0.94
# batch no. 280, training accuracy 0.74
# Validation accuracy : 0.782
# batch no. 282, training accuracy 0.94
# batch no. 284, training accuracy 0.96
# batch no. 286, training accuracy 1.00
# batch no. 288, training accuracy 0.94
# batch no. 290, training accuracy 0.76
# Validation accuracy : 0.775
# batch no. 292, training accuracy 0.86
# batch no. 294, training accuracy 0.96
# batch no. 296, training accuracy 0.92
# batch no. 298, training accuracy 0.92
# batch no. 300, training accuracy 0.66
# Validation accuracy : 0.78
# batch no. 302, training accuracy 0.94
# batch no. 304, training accuracy 0.88
# batch no. 306, training accuracy 0.82
# batch no. 308, training accuracy 0.86
# batch no. 310, training accuracy 0.76
# Validation accuracy : 0.781
# batch no. 312, training accuracy 0.92
# batch no. 314, training accuracy 0.94
# batch no. 316, training accuracy 0.90
# batch no. 318, training accuracy 0.92
# batch no. 320, training accuracy 0.72
# Validation accuracy : 0.776
# batch no. 322, training accuracy 0.92
# batch no. 324, training accuracy 0.94
# batch no. 326, training accuracy 0.92
# batch no. 328, training accuracy 0.94
# batch no. 330, training accuracy 0.82
# Validation accuracy : 0.786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-886220646a79> in <module>()
#      24           if t%1000 == 0:
#      25             break
# ---> 26           update_policy()
#      27       #running_reward = 0.05 * policy_model.reward_episode + (1 - 0.05) * running_reward
#      28       #print("Epoch %d, reward %4.2f" % (epoch, running_reward))
#
# <ipython-input-60-bc7fbe282ef5> in update_policy()
#      22     policy_loss =  J1 +  (J2/len(policy_model.rewards)) + J3
#      23     # print('policy_loss', policy_loss)
# ---> 24     policy_loss.backward(retain_graph=True)
#      25     optimizer.step()
#      26
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
torch.save(policy_model.state_dict(), 'jump_model.weights')

# %% [markdown]
# # Evaluating

# %%
import timeit
import spacy
import matplotlib.pyplot as plt
nlp = spacy.load('en')

def predict_sentiment(model, sentence):
    model.train_mode = False
    tokenized = [tok.text for tok in nlp.tokenizer(sentence)]
    indexed = [TEXT.vocab.stoi[t] for t in tokenized]
    # tensor = torch.LongTensor(indexed).to(device)
    tensor = torch.LongTensor(indexed).to('cpu')
    tensor = tensor.unsqueeze(1)
    model((tensor, torch.tensor([tensor.shape[0]]), None))
    res = torch.sigmoid(model.label_predictions[0])
    model.train_mode = False
    return res

times = []
lengths=[]
train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size=1,
    device=device,
    shuffle = True,
    # sort_key=lambda x: len(x.text),
    sort_within_batch=False)

i = 0
for _data in test_iterator:
    if i%100 == 0:
        # get the inputs
        texts, text_lengths, labels = _data.text[0], _data.text[1], _data.label
        # print(texts.shape, text_lengths.shape, labels.shape)
        start_time = timeit.default_timer()
        predictions = policy_model((texts.to(device), text_lengths.to(device), labels.to(device)))
        elapsed = timeit.default_timer() - start_time
        lengths.append(texts.shape[0])
        times.append(elapsed)
        # print("Input review texts, text_lengths, labels", texts.shape, text_lengths.shape, labels.shape)
    if i>20000:
        break
    i += 1

import pickle

pickle_out = open("test_times.pickle","wb")
pickle.dump((lengths, times), pickle_out)
pickle_out.close()

pickle_in_1 = open("test_times_1.pickle","rb")
(lengths_1, times_1) = pickle.load(pickle_in_1)

pickle_in_2 = open("test_times_2.pickle","rb")
(lengths_2, times_2) = pickle.load(pickle_in_2)

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

plt.scatter(lengths, times, label='skip-model')
plt.scatter(lengths_1, times_1, label='fast-model')
plt.scatter(lengths_2, times_2, label='simple-lstm-model')
plt.xlabel('Lengths of review')
plt.ylabel('Time taken for prediction (sec)')
plt.title('Time taken for evaluation/prediction only')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
import pickle
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

average_time_per_iter = 4.76
average_time_per_iter_1 = 9.2
average_time_per_iter_2 = 65.1

pickle_out = open("training_epochs.pickle","wb")
pickle.dump((policy_model.training_accuracies, policy_model.validation_accuracies), pickle_out)
pickle_out.close()

pickle_in_1 = open("training_epochs_1.pickle","rb")
(training_accuracies_1, validation_accuracies_1) = pickle.load(pickle_in_1)

pickle_in_2 = open("training_epochs_2.pickle","rb")
(training_accuracies_2, validation_accuracies_2) = pickle.load(pickle_in_2)

ystep = 5
_ystep = 100

y = moving_average(policy_model.validation_accuracies[::ystep])
_y = moving_average(policy_model.training_accuracies[::_ystep])
x = np.linspace(0, num=len(y), stop=len(y)*ystep*average_time_per_iter)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter)

#plt.plot(x, y, label='skip-model validation accuracy')
plt.plot(_x, _y, label='skip-model train accuracy')

ystep = 5
_ystep = 100

#y = moving_average(validation_accuracies_1[::ystep])
_y = moving_average(training_accuracies_1[::_ystep])
x = np.linspace(0, num=len(y), stop=len(y)*ystep*average_time_per_iter_1)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter_1)

#plt.plot(x, y, label='fast-model validationa accuracy')
plt.plot(_x, _y, label='fast-model train accuracy')

ystep = 5
_ystep = 100

#y = moving_average(validation_accuracies_2[::ystep])
_y = moving_average(training_accuracies_2[::_ystep])
x = np.linspace(0, num=len(y), stop=len(y)*ystep*average_time_per_iter_2)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter_2)

#plt.plot(x, y, label='simple-lstm-model validation accuracy')
plt.plot(_x, _y, label='simple-lstm-model train accuracy')

plt.xlabel('Training Time (s)')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracies over time for different models')
plt.legend()
plt.show()

figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

ystep = 5
_ystep = 100

y = moving_average(policy_model.validation_accuracies[::ystep])
_y = moving_average(policy_model.training_accuracies[::_ystep])
x = np.linspace(0, num=len(y), stop=len(_y)*_ystep*average_time_per_iter)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter)

plt.plot(x, y, label='skip-model validation accuracy')

ystep = 5
_ystep = 100

y = moving_average(validation_accuracies_1[::ystep])
_y = moving_average(training_accuracies_1[::_ystep])
x = np.linspace(0, num=len(y), stop=len(_y)*_ystep*average_time_per_iter_1)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter_1)

plt.plot(x, y, label='fast-model validationa accuracy')

ystep = 5
_ystep = 100

y = moving_average(validation_accuracies_2[::ystep])
_y = moving_average(training_accuracies_2[::_ystep])
x = np.linspace(0, num=len(y), stop=len(_y)*_ystep*average_time_per_iter_2)
_x = np.linspace(0, num=len(_y), stop=len(_y)*_ystep*average_time_per_iter_2)

plt.plot(x, y, label='simple-lstm-model validation accuracy')

plt.xlabel('Training Time (s)')
plt.ylabel('Validation Accuracy')
plt.title('Validation Accuracies over time for different models')
plt.legend()
plt.show()
